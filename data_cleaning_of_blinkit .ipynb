# %%
import pandas as pd

# %%
cf=pd.read_csv("OneDrive/Documents/Blinkit Project/customer_feedback.csv")

# %%
cust=pd.read_csv("OneDrive/Documents/Blinkit Project/customers.csv")

# %%
del_perf=pd.read_csv("OneDrive/Documents/Blinkit Project/delivery_performance.csv")

# %%
inv=pd.read_csv("OneDrive/Documents/Blinkit Project/inventory.csv")

# %%
mark_perf=pd.read_csv("OneDrive/Documents/Blinkit Project/marketing_performance.csv")

# %%
order_items=pd.read_csv("OneDrive/Documents/Blinkit Project/order_items.csv")

# %%
orders=pd.read_csv("OneDrive/Documents/Blinkit Project/orders.csv")

# %%
products=pd.read_csv("OneDrive/Documents/Blinkit Project/products.csv")

# %% [markdown]
# <font size= 6>**DATA CLEANING**</font>

# %%
cf
# Out:
#       feedback_id    order_id  customer_id  rating  \
# 0         2234710  1961864118     30065862       4
# 1         5450964  1549769649      9573071       3
# 2          482108  9185164487     45477575       3
# 3         4823104  9644738826     88067569       4
# 4         3537464  5427684290     83298567       3
# ...           ...         ...          ...     ...
# 4995      9024060  1669690997     62600289       3
# 4996      4715968  8340761903     53640286       3
# 4997      9621021  5936301790     87059497       4
# 4998      1134095  5710579377     67310893       4
# 4999      6578433  2494813730     28663279       4
#
#                              feedback_text feedback_category sentiment  \
# 0            It was okay, nothing special.          Delivery   Neutral
# 1                 The order was incorrect.    App Experience  Negative
# 2            It was okay, nothing special.    App Experience   Neutral
# ...

# %%
cf.sort_values("feedback_id")
# Out:
#       feedback_id    order_id  customer_id  rating  \
# 1451          947  8875605037     93867669       1
# 324          5028  8830321199     93341057       5
# 2539         5348   935645101     63368244       3
# 2181         6201  9271384187     67749649       1
# 4612        11042  1320638425     36833857       4
# ...           ...         ...          ...     ...
# 3889      9992406  7485459856     89784343       4
# 1926      9992700  8310385249     97315135       1
# 4726      9993994  1225289500     70529459       1
# 4197      9997264  5953426781     79135318       4
# 3083      9999293  3770123374     29415527       4
#
#                                           feedback_text feedback_category  \
# 1451                  Customer service was not helpful.    App Experience
# 324                       Very fresh and well-packaged.   Product Quality
# 2539                        Not worth the price I paid.   Product Quality
# ...

# %%
cf.dtypes
# Out:
# feedback_id                   int64
# order_id                      int64
# customer_id                   int64
# rating                        int64
# feedback_text                object
# feedback_category            object
# sentiment                    object
# feedback_date        datetime64[ns]
# dtype: object

# %%
cf.isnull().sum()
# Out:
# feedback_id          0
# order_id             0
# customer_id          0
# rating               0
# feedback_text        0
# feedback_category    0
# sentiment            0
# feedback_date        0
# dtype: int64

# %%
cf[cf.duplicated()]
# Out:
# Empty DataFrame
# Columns: [feedback_id, order_id, customer_id, rating, feedback_text, feedback_category, sentiment, feedback_date]
# Index: []

# %%
cf["feedback_date"]=pd.to_datetime(cf["feedback_date"],errors="")

# %%
cf.to_csv("OneDrive/Documents/Blinkit Project/customer_feedback.csv",index=False)

# %%
#=======================================
#customer_feedback table is cleaned 
#=======================================

# %%
cust
# Out:
#       customer_id      customer_name                        email  \
# 0        97475543      Niharika Nagi       ektataneja@example.org
# 1        22077605       Megha Sachar         vedant45@example.com
# 2        47822591         Hema Bahri        samiazaan@example.com
# 3        79726146         Zaitra Vig        ishanvi87@example.org
# 4        57102800       Januja Verma     atideshpande@example.org
# ...           ...                ...                          ...
# 2495     48002829       Daksh Mandal   varkeymohammed@example.com
# 2496     57392064       Lavanya Jain      deshpandeom@example.com
# 2497     71688530         Umang Dash  gokhalenicholas@example.org
# 2498     89051578    Zinal Natarajan        vyasfrado@example.com
# 2499     78738569  Eiravati Sundaram          onkar24@example.com
#
#              phone                                       address  \
# 0     912987579691           23, Nayar Path, Bihar Sharif-154625
# ...

# %%
cust.dtypes
# Out:
# customer_id            int64
# customer_name         object
# email                 object
# phone                  int64
# address               object
# area                  object
# pincode                int64
# registration_date     object
# customer_segment      object
# total_orders           int64
# avg_order_value      float64
# dtype: object

# %%
cust.isnull().sum()
# Out:
# customer_id          0
# customer_name        0
# email                0
# phone                0
# address              0
# area                 0
# pincode              0
# registration_date    0
# customer_segment     0
# total_orders         0
# avg_order_value      0
# dtype: int64

# %%
cust[cust.duplicated()]
# Out:
# Empty DataFrame
# Columns: [customer_id, customer_name, email, phone, address, area, pincode, registration_date, customer_segment, total_orders, avg_order_value]
# Index: []

# %%
#=======================================
#customers table is cleaned 
#=======================================

# %%
del_perf
# Out:
#         order_id  delivery_partner_id        promised_time  \
# 0     1961864118                63230  2024-07-17 08:52:01
# 1     1549769649                14983  2024-05-28 13:25:29
# 2     9185164487                39859  2024-09-23 13:25:12
# 3     9644738826                61497  2023-11-24 16:34:56
# 4     5427684290                84315  2023-11-20 05:17:39
# ...          ...                  ...                  ...
# 4995  1669690997                90914  2023-12-25 16:05:20
# 4996  8340761903                27952  2023-11-27 09:38:43
# 4997  5936301790                 9590  2024-06-21 19:23:09
# 4998  5710579377                29940  2024-06-06 15:12:13
# 4999  2494813730                32851  2023-08-23 12:20:18
#
#               actual_time  delivery_time_minutes  distance_km delivery_status  \
# 0     2024-07-17 08:47:01                   -5.0         0.96         On Time
# 1     2024-05-28 13:27:29                    2.0         0.98         On Time
# ...

# %%
del_perf.dtype
# Out:
# order_id                   int64
# delivery_partner_id        int64
# promised_time             object
# actual_time               object
# delivery_time_minutes    float64
# distance_km              float64
# delivery_status           object
# reasons_if_delayed        object
# dtype: object

# %%
del_perf.isnull().sum
# Out:
# order_id                    0
# delivery_partner_id         0
# promised_time               0
# actual_time                 0
# delivery_time_minutes       0
# distance_km                 0
# delivery_status             0
# reasons_if_delayed       1902
# dtype: int64

# %%
del_perf[del_perf.duplicated()]
# Out:
# Empty DataFrame
# Columns: [order_id, delivery_partner_id, promised_time, actual_time, delivery_time_minutes, distance_km, delivery_status, reasons_if_delayed]
# Index: []

# %%
#=======================================
#delivery performance table is cleaned 
#=======================================

# %%
inv
# Out:
#        product_id       date  stock_received  damaged_stock
# 0          153019 2023-03-17               4              2
# 1          848226 2023-03-17               4              2
# 2          965755 2023-03-17               1              0
# 3           39154 2023-03-17               4              0
# 4           34186 2023-03-17               3              2
# ...           ...        ...             ...            ...
# 75167      298985 2024-11-05               3              0
# 75168      679284 2024-11-05               3              0
# 75169      240179 2024-11-05               3              0
# 75170      673058 2024-11-05               3              2
# 75171      114414 2024-11-05               3              0
#
# [75172 rows x 4 columns]

# %%
inv.isnull().sum()
# Out:
# product_id        0
# date              0
# stock_received    0
# damaged_stock     0
# dtype: int64

# %%
inv.dtypes
# Out:
# product_id                 int64
# date              datetime64[ns]
# stock_received             int64
# damaged_stock              int64
# dtype: object

# %%
inv["date"]=pd.to_datetime(inv["date"],errors="coerce",format="%Y-%m-%d")

# %%
inv[inv["product_id"].duplicated()]
# Out:
#        product_id       date  stock_received  damaged_stock
# 113        153019 2023-03-18               0              2
# 117         34186 2023-03-18               0              2
# 119        818990 2023-03-18               1              0
# 121        284460 2023-03-18               0              2
# 125        217710 2023-03-18               0              2
# ...           ...        ...             ...            ...
# 75167      298985 2024-11-05               3              0
# 75168      679284 2024-11-05               3              0
# 75169      240179 2024-11-05               3              0
# 75170      673058 2024-11-05               3              2
# 75171      114414 2024-11-05               3              0
#
# [74904 rows x 4 columns]

# %%
inv.to_csv(r"C:\Users\prath\OneDrive\Documents\Blinkit Project\inventory.csv",index=False)

# %%
#=======================================
#inventory table is cleaned 
#=======================================

# %%
mark_perf
# Out:
#       campaign_id          campaign_name        date target_audience  \
# 0          548299      New User Discount  2024-11-05         Premium
# 1          390914        Weekend Special  2024-11-05        Inactive
# 2          834385         Festival Offer  2024-11-05        Inactive
# 3          241523             Flash Sale  2024-11-05        Inactive
# 4          595111       Membership Drive  2024-11-05       New Users
# ...           ...                    ...         ...             ...
# 5395       381623       Membership Drive  2023-03-17       New Users
# 5396       493317     Category Promotion  2023-03-17         Premium
# 5397       879292  App Push Notification  2023-03-17             All
# 5398       461129         Email Campaign  2023-03-17       New Users
# 5399       282514       Referral Program  2023-03-17       New Users
#
#            channel  impressions  clicks  conversions    spend  \
# 0              App         3130     163           78  1431.85
# ...

# %%
mark_perf.dtypes
# Out:
# campaign_id            int64
# campaign_name         object
# date                  object
# target_audience       object
# channel               object
# impressions            int64
# clicks                 int64
# conversions            int64
# spend                float64
# revenue_generated    float64
# roas                 float64
# dtype: object

# %%
mark_perf.isnull().sum()
# Out:
# campaign_id          0
# campaign_name        0
# date                 0
# target_audience      0
# channel              0
# impressions          0
# clicks               0
# conversions          0
# spend                0
# revenue_generated    0
# roas                 0
# dtype: int64

# %%
mark_perf[mark_perf["campaign_id"].duplicated()]
# Out:
# Empty DataFrame
# Columns: [campaign_id, campaign_name, date, target_audience, channel, impressions, clicks, conversions, spend, revenue_generated, roas]
# Index: []

# %%
#=======================================
#marketing performance table is cleaned 
#=======================================

# %%
order_items
# Out:
#         order_id  product_id  quantity  unit_price
# 0     1961864118      642612         3      517.03
# 1     1549769649      378676         1      881.42
# 2     9185164487      741341         2      923.84
# 3     9644738826      561860         1      874.78
# 4     5427684290      602241         2      976.55
# ...          ...         ...       ...         ...
# 4995  1669690997      925482         3      475.04
# 4996  8340761903      124290         2       39.65
# 4997  5936301790      491314         3      973.44
# 4998  5710579377      319388         2      657.80
# 4999  2494813730      136533         1      826.21
#
# [5000 rows x 4 columns]

# %%
order_items.isnull().sum()
# Out:
# order_id      0
# product_id    0
# quantity      0
# unit_price    0
# dtype: int64

# %%
order_items.dtypes
# Out:
# order_id        int64
# product_id      int64
# quantity        int64
# unit_price    float64
# dtype: object

# %%
order_items[order_items["order_id"].duplicated()]
# Out:
# Empty DataFrame
# Columns: [order_id, product_id, quantity, unit_price]
# Index: []

# %%
#=======================================
#order items table is cleaned 
#=======================================

# %%
orders
# Out:
#         order_id  customer_id           order_date promised_delivery_time  \
# 0     1961864118     30065862  2024-07-17 08:34:01    2024-07-17 08:52:01
# 1     1549769649      9573071  2024-05-28 13:14:29    2024-05-28 13:25:29
# 2     9185164487     45477575  2024-09-23 13:07:12    2024-09-23 13:25:12
# 3     9644738826     88067569  2023-11-24 16:16:56    2023-11-24 16:34:56
# 4     5427684290     83298567  2023-11-20 05:00:39    2023-11-20 05:17:39
# ...          ...          ...                  ...                    ...
# 4995  1669690997     62600289  2023-12-25 15:46:20    2023-12-25 16:05:20
# 4996  8340761903     53640286  2023-11-27 09:18:43    2023-11-27 09:38:43
# 4997  5936301790     87059497  2024-06-21 19:09:09    2024-06-21 19:23:09
# 4998  5710579377     67310893  2024-06-06 14:58:13    2024-06-06 15:12:13
# 4999  2494813730     28663279  2023-08-23 12:04:18    2023-08-23 12:20:18
#
#      actual_delivery_time delivery_status  order_total payment_method  \
# ...

# %%
orders.isnull().sum()
# Out:
# order_id                  0
# customer_id               0
# order_date                0
# promised_delivery_time    0
# actual_delivery_time      0
# delivery_status           0
# order_total               0
# payment_method            0
# delivery_partner_id       0
# store_id                  0
# dtype: int64

# %%
orders.dtypes
# Out:
# order_id                    int64
# customer_id                 int64
# order_date                 object
# promised_delivery_time     object
# actual_delivery_time       object
# delivery_status            object
# order_total               float64
# payment_method             object
# delivery_partner_id         int64
# store_id                    int64
# dtype: object

# %%
orders[orders["order_id"].duplicated()]
# Out:
# Empty DataFrame
# Columns: [order_id, customer_id, order_date, promised_delivery_time, actual_delivery_time, delivery_status, order_total, payment_method, delivery_partner_id, store_id]
# Index: []

# %%
#=======================================
#order table is cleaned 
#=======================================

# %%
products
# Out:
#      product_id   product_name             category                    brand  \
# 0        153019         Onions  Fruits & Vegetables               Aurora LLC
# 1         11422       Potatoes  Fruits & Vegetables           Ramaswamy-Tata
# 2        669378       Potatoes  Fruits & Vegetables          Chadha and Sons
# 3        848226       Tomatoes  Fruits & Vegetables           Barad and Sons
# 4        890623         Onions  Fruits & Vegetables  Sangha, Nagar and Varty
# ..          ...            ...                  ...                      ...
# 263      444361  Pain Reliever             Pharmacy   Prakash, Bawa and Kale
# 264      679284    Cough Syrup             Pharmacy                 Pant LLC
# 265      240179    Cough Syrup             Pharmacy                 Ram-Suri
# 266      673058    Cough Syrup             Pharmacy              Balan-Madan
# 267      114414       Vitamins             Pharmacy               Kara-Golla
#
# ...

# %%
products.describe()
# Out:
#           product_id       price          mrp  margin_percentage  \
# count     268.000000  268.000000   268.000000         268.000000
# mean   514855.940299  488.356828   680.434739          27.779851
# std    291391.529820  298.487200   419.772224           7.458753
# min      4452.000000   12.320000    17.600000          15.000000
# 25%    273697.750000  226.717500   325.150000          20.000000
# 50%    541459.000000  442.185000   616.970000          30.000000
# 75%    754334.000000  779.445000  1056.620000          35.000000
# max    993331.000000  995.980000  1633.320000          40.000000
#
#        shelf_life_days  min_stock_level  max_stock_level
# count       268.000000       268.000000       268.000000
# mean        231.757463        20.388060        74.753731
# std         151.205830         5.958546        14.591535
# min           3.000000        10.000000        50.000000
# 25%          90.000000        15.000000        63.750000
# ...

# %%
products["category"].value_counts().sort_index()
# Out:
# category
# Baby Care                16
# Cold Drinks & Juices     22
# Dairy & Breakfast        30
# Fruits & Vegetables      27
# Grocery & Staples        24
# Household Care           27
# Instant & Frozen Food    20
# Personal Care            25
# Pet Care                 25
# Pharmacy                 25
# Snacks & Munchies        27
# Name: count, dtype: int64

# %%
products.isnull().sum()
# Out:
# product_id           0
# product_name         0
# category             0
# brand                0
# price                0
# mrp                  0
# margin_percentage    0
# shelf_life_days      0
# min_stock_level      0
# max_stock_level      0
# dtype: int64

# %%
products.dtypes
# Out:
# product_id             int64
# product_name          object
# category              object
# brand                 object
# price                float64
# mrp                  float64
# margin_percentage    float64
# shelf_life_days        int64
# min_stock_level        int64
# max_stock_level        int64
# dtype: object

# %%
products[products["product_id"].duplicated()]
# Out:
# Empty DataFrame
# Columns: [product_id, product_name, category, brand, price, mrp, margin_percentage, shelf_life_days, min_stock_level, max_stock_level]
# Index: []

# %%
#=======================================
#products table is cleaned 
#=======================================
